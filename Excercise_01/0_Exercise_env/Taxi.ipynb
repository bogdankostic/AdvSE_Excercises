# %%
# !pip install -r requirements.txt
# Out:
# Collecting pandas (from -r requirements.txt (line 1))
#   Downloading pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting scikit-learn (from -r requirements.txt (line 2))
#   Downloading scikit_learn-1.4.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting matplotlib (from -r requirements.txt (line 4))
#   Downloading matplotlib-3.8.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting seaborn (from -r requirements.txt (line 5))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: jupyter in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Collecting gymnasium (from -r requirements.txt (line 8))
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.22.4 (from pandas->-r requirements.txt (line 1))
#   Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 1))
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 1))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->-r requirements.txt (line 2))
#   Downloading scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 2))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r requirements.txt (line 2))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r requirements.txt (line 4))
#   Downloading contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements.txt (line 4))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r requirements.txt (line 4))
#   Downloading fonttools-4.51.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 7.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r requirements.txt (line 4))
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 4)) (24.0)
# Collecting pillow>=8 (from matplotlib->-r requirements.txt (line 4))
#   Downloading pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r requirements.txt (line 4))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: notebook in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (7.1.3)
# Requirement already satisfied: qtconsole in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: jupyter-console in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (6.29.4)
# Requirement already satisfied: ipywidgets in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (8.1.2)
# Collecting cloudpickle>=1.2.0 (from gymnasium->-r requirements.txt (line 8))
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from gymnasium->-r requirements.txt (line 8)) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium->-r requirements.txt (line 8))
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: six>=1.5 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: appnope in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.24.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (3.0.43)
# Requirement already satisfied: pygments in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (4.1.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from qtconsole->jupyter->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: webencodings in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: decorator in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: stack-data in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 6)) (4.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (4.22.0)
# Requirement already satisfied: requests>=2.31 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: wcwidth in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: idna>=2.8 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: certifi in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: fqdn in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.4)
# Requirement already satisfied: uri-template in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: pycparser in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.9.0.20240316)
# Downloading pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 12.2 MB/s eta 0:00:0000:0100:01
# Downloading scikit_learn-1.4.2-cp310-cp310-macosx_12_0_arm64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 42.2 MB/s eta 0:00:0000:010:01
# Downloading matplotlib-3.8.4-cp310-cp310-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 43.4 MB/s eta 0:00:00a 0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 30.5 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 46.5 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 24.4 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading fonttools-4.51.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 43.5 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 29.7 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
# Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 27.6 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.2 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 16.6 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 45.3 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, farama-notifications, tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, cloudpickle, scipy, pandas, gymnasium, contourpy, scikit-learn, matplotlib, seaborn
# Successfully installed cloudpickle-3.0.0 contourpy-1.2.1 cycler-0.12.1 farama-notifications-0.0.4 fonttools-4.51.0 gymnasium-0.29.1 joblib-1.4.2 kiwisolver-1.4.5 matplotlib-3.8.4 numpy-1.26.4 pandas-2.2.2 pillow-10.3.0 pyparsing-3.1.2 pytz-2024.1 scikit-learn-1.4.2 scipy-1.13.0 seaborn-0.13.2 threadpoolctl-3.5.0 tzdata-2024.1

# %%
# !pip install cmake scipy pygame
# Out:
# Collecting cmake
#   Downloading cmake-3.29.3-py3-none-macosx_10_10_universal2.macosx_10_10_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl.metadata (6.1 kB)
# Requirement already satisfied: scipy in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (1.13.0)
# Collecting pygame
#   Downloading pygame-2.5.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages (from scipy) (1.26.4)
# Downloading cmake-3.29.3-py3-none-macosx_10_10_universal2.macosx_10_10_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (51.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 MB 40.7 MB/s eta 0:00:0000:0100:01
# Downloading pygame-2.5.2-cp310-cp310-macosx_11_0_arm64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 29.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pygame, cmake
# Successfully installed cmake-3.29.3 pygame-2.5.2

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
from IPython.display import clear_output
from time import sleep
from matplotlib import animation

# %%
"""Initialize and validate the environment"""
env = gym.make("Taxi-v3", render_mode="rgb_array").env
state, _ = env.reset()

# Print dimensions of state and action space
print("State space: {}".format(env.observation_space))
print("Action space: {}".format(env.action_space))

# Sample random action
action = env.action_space.sample(env.action_mask(state))
next_state, reward, done, _, _ = env.step(action)

# Print output
print("State: {}".format(state))
print("Action: {}".format(action))
print("Action mask: {}".format(env.action_mask(state)))
print("Reward: {}".format(reward))

# Render and plot an environment frame
frame = env.render()
plt.imshow(frame)
plt.axis("off")
plt.show()
# Out:
# State space: Discrete(500)
# Action space: Discrete(6)
# State: 9
# Action: 2
# Action mask: [1 0 1 0 0 0]
# Reward: -1
# /Users/bogdan/miniconda3/envs/ase/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.action_mask to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_mask` for environment variables or `env.get_wrapper_attr('action_mask')` that will search the reminding wrappers.
#   logger.warn(

# %%
def run_animation(experience_buffer):
    """Function to run animation"""
    time_lag = 0.05  # Delay (in s) between frames
    for experience in experience_buffer:
        # Plot frame
        clear_output(wait=True)
        plt.imshow(experience['frame'])
        plt.axis('off')
        plt.show()

        # Print console output
        print(f"Episode: {experience['episode']}/{experience_buffer[-1]['episode']}")
        print(f"Epoch: {experience['epoch']}/{experience_buffer[-1]['epoch']}")
        print(f"State: {experience['state']}")
        print(f"Action: {experience['action']}")
        print(f"Reward: {experience['reward']}")
        # Pauze animation
        sleep(time_lag)

# %%
def store_episode_as_gif(experience_buffer, path='./', filename='animation.gif'):
    """Store episode as gif animation"""
    fps = 5   # Set framew per seconds
    dpi = 300  # Set dots per inch
    interval = 50  # Interval between frames (in ms)

    # Retrieve frames from experience buffer
    frames = []
    for experience in experience_buffer:
        frames.append(experience['frame'])

    # Fix frame size
    plt.figure(figsize=(frames[0].shape[1] / dpi, frames[0].shape[0] / dpi), dpi=dpi)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    # Generate animation
    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=interval)

    # Save output as gif
    anim.save(path + filename, writer='imagemagick', fps=fps)

# %% [markdown]
# ### Testing a random agent

# %%
"""Simulation with random agent"""
epoch = 0
num_failed_dropoffs = 0
experience_buffer = []
cum_reward = 0

done = False

state, _ = env.reset()

while not done:
    # Sample random action
    "Action selection without action mask"
    action = env.action_space.sample()

    "Action selection with action mask"
    #action = env.action_space.sample(env.action_mask(state))

    state, reward, done, _, _ = env.step(action)
    cum_reward += reward

    # Store experience in dictionary
    experience_buffer.append({
        "frame": env.render(),
        "episode": 1,
        "epoch": epoch,
        "state": state,
        "action": action,
        "reward": cum_reward,
        }
    )

    if reward == -10:
        num_failed_dropoffs += 1

    epoch += 1

# Run animation and print console output
run_animation(experience_buffer)

print("# epochs: {}".format(epoch))
print("# failed drop-offs: {}".format(num_failed_dropoffs))
# Out:
# Episode: 1/1
# Epoch: 1751/1751
# State: 475
# Action: 5
# Reward: -7005
# # epochs: 1752
# # failed drop-offs: 586

# %% [markdown]
# ### Training the agent

# %%
"""Training the agent"""
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %%
# Hyperparameters
alpha = 0.1  # Learning rate
gamma = 1.0  # Discount rate
epsilon = 0.1  # Exploration rate
num_episodes = 10000  # Number of episodes

# Output for plots
cum_rewards = np.zeros([num_episodes])
total_epochs = np.zeros([num_episodes])

# %%
for episode in range(1, num_episodes+1):
    # Reset environment
    state, info = env.reset()
    epoch = 0 
    num_failed_dropoffs = 0
    done = False
    cum_reward = 0

    while not done:
        
        if random.uniform(0, 1) < epsilon:
            "Basic exploration [~0.47m]"
            action = env.action_space.sample() # Sample random action (exploration)
            
            "Exploration with action mask [~1.52m]"
          # action = env.action_space.sample(env.action_mask(state)) "Exploration with action mask"
        else:      
            "Exploitation with action mask [~1m52s]"
           # action_mask = np.where(info["action_mask"]==1,0,1) # invert
           # masked_q_values = np.ma.array(q_table[state], mask=action_mask, dtype=np.float32)
           # action = np.ma.argmax(masked_q_values, axis=0)

            "Exploitation with random tie breaker [~1m19s]"
          #  action = np.random.choice(np.flatnonzero(q_table[state] == q_table[state].max()))
            
            "Basic exploitation [~47s]"
            action = np.argmax(q_table[state]) # Select best known action (exploitation)
 
        next_state, reward, done, _ , info = env.step(action) 

        cum_reward += reward
        
        old_q_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        
        new_q_value = (1 - alpha) * old_q_value + alpha * (reward + gamma * next_max)
        
        q_table[state, action] = new_q_value
        
        if reward == -10:
            num_failed_dropoffs += 1

        state = next_state
        epoch += 1
        
        total_epochs[episode-1] = epoch
        cum_rewards[episode-1] = cum_reward

    if episode % 100 == 0:
        clear_output(wait=True)
        print(f"Episode #: {episode}")

print("\n")
print("===Training completed.===\n")
# Out:
# Episode #: 10000
#
#
# ===Training completed.===

# %%
# Plot reward convergence
plt.title("Cumulative reward per episode")
plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.plot(cum_rewards)
plt.show()

# Plot epoch convergence
plt.title("# epochs per episode")
plt.xlabel("Episode")
plt.ylabel("# epochs")
plt.plot(total_epochs)
plt.show()

# %% [markdown]
# ### Testing the policy

# %%
"""Test policy performance after training"""

num_epochs = 0
total_failed_deliveries = 0
num_episodes = 1
experience_buffer = []
store_gif = True

for episode in range(1, num_episodes+1):
    # Initialize experience buffer

    my_env = env.reset()
    state = my_env[0]
    epoch = 1 
    num_failed_deliveries =0
    cum_reward = 0
    done = False

    while not done:
        action = np.argmax(q_table[state])
        state, reward, done, _, _ = env.step(action)
        cum_reward += reward

        if reward == -10:
            num_failed_deliveries += 1

        # Store rendered frame in animation dictionary
        experience_buffer.append({
            'frame': env.render(),
            'episode': episode,
            'epoch': epoch,
            'state': state,
            'action': action,
            'reward': cum_reward
            }
        )

        epoch += 1

    total_failed_deliveries += num_failed_deliveries
    num_epochs += epoch

    if store_gif:
        store_episode_as_gif(experience_buffer)

# Run animation and print output
run_animation(experience_buffer)
# Out:
# Episode: 1/1
# Epoch: 15/15
# State: 410
# Action: 5
# Reward: 6

# %%
# Print final results
print("\n") 
print(f"Test results after {num_episodes} episodes:")
print(f"Mean # epochs per episode: {num_epochs / num_episodes}")
print(f"Mean # failed drop-offs per episode: {total_failed_deliveries / num_episodes}")
# Out:
# Test results after 1 episodes:
# Mean # epochs per episode: 16.0
# Mean # failed drop-offs per episode: 0.0
